# %% [markdown]
# ### Read csv file using pandas

# %%
import pandas as pd
who = pd.read_csv("WHO.csv", parse_dates=["Date_reported"])  #parse date to convert date into date time
who.head(5)
# Out:
#   Date_reported Country  New_cases  Cumulative_cases  New_deaths  \
# 0    2020-01-04   China          1                 1           0
# 1    2020-01-05   China          0                 1           0
# 2    2020-01-06   China          3                 4           0
# 3    2020-01-07   China          0                 4           0
# 4    2020-01-08   China          0                 4           0
#
#    Cumulative_deaths
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0

# %% [markdown]
# ---

# %% [markdown]
# #### Filter to extract italy data from overall data

# %%
italy = who[who["Country"] == "Italy"]  #filter to extract italy data from overall data
italy
# Out:
#       Date_reported Country  New_cases  Cumulative_cases  New_deaths  \
# 123      2020-01-29   Italy          6                 6           0
# 144      2020-01-30   Italy          0                 6           0
# 158      2020-01-31   Italy          0                 6           0
# 187      2020-02-01   Italy          0                 6           0
# 215      2020-02-02   Italy          0                 6           0
# ...             ...     ...        ...               ...         ...
# 30870    2020-07-27   Italy        254            246118           5
# 31097    2020-07-28   Italy        168            246286           5
# 31333    2020-07-29   Italy        202            246488          11
# 31629    2020-07-30   Italy        288            246776           6
# 31686    2020-07-31   Italy        382            247158           3
#
#        Cumulative_deaths
# 123                    0
# 144                    0
# 158                    0
# 187                    0
# ...

# %%
who.head(5)
# Out:
#   Date_reported Country  New_cases  Cumulative_cases  New_deaths  \
# 0    2020-01-04   China          1                 1           0
# 1    2020-01-05   China          0                 1           0
# 2    2020-01-06   China          3                 4           0
# 3    2020-01-07   China          0                 4           0
# 4    2020-01-08   China          0                 4           0
#
#    Cumulative_deaths
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0

# %%
who.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31876 entries, 0 to 31875
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date_reported      31876 non-null  datetime64[ns]
#  1   Country            31876 non-null  object
#  2   New_cases          31876 non-null  int64
#  3   Cumulative_cases   31876 non-null  int64
#  4   New_deaths         31876 non-null  int64
#  5   Cumulative_deaths  31876 non-null  int64
# dtypes: datetime64[ns](1), int64(4), object(1)
# memory usage: 1.5+ MB

# %% [markdown]
# ---

# %% [markdown]
# ### Line chart between Date Reported and Cumulative Class for Italy data
# Here:
# * x is independent variable
# * y is dependent variable

# %%
# here matplotlib is library and pyplot is its class and plt stand for plot
import matplotlib.pyplot as plt 
plt.title("Italy: Covid Cumulative Cases")
plt.xlabel("Date")
plt.ylabel("Cumulative Cases")
plt.plot(italy.Date_reported, italy.Cumulative_cases)
plt.show()

# %% [markdown]
# ### Graphs / Regression:
# * Growth graphs - Exponential growth, Linear growth, Logarithm growth, Logistic growth
# * Decline graphs - Exponential decline, Linear decline, Logarithm decline, Logistic decline
# * Irregular graph
#
# Key Point: Logistic growth graph starts with - exponential growth and eventually ends at logistic growth.

# %% [markdown]
# #### Creating function to extract particular country data from overall data and to plot its graph.

# %%
def line_chart(Country):
    c_df = who[who["Country"] == Country]
    plt.title(f"{Country} : Covid Cummulative Cases")    #title of the graph
    plt.xlabel("Date")                                    #x-axis label of the graph
    plt.ylabel("Cummulative Cases")                       #y-axis label of the graph
    plt.ticklabel_format(axis = "Y", style = "plain")     # to remove exponent from y-axis 
    plt.plot(c_df.Date_reported, c_df.Cumulative_cases)
    plt.show()

# %% [markdown]
# * Graph between Data and Cumulative Cases for India data \
#   Result=> Exponential Growth Graph:

# %%
line_chart("India")            # graph of India using function

# %% [markdown]
# * Graph between Data and Cumulative Cases for India data \
#   Result=> Linear Growth Graph:

# %%
line_chart("Poland")            # graph of Poland using function

# %% [markdown]
# * Graph between Data and Cumulative Cases for India data \
#   Result=> Logistic Growth Graph:

# %%
line_chart("Italy")            # graph of Italy using function

# %% [markdown]
# ---

# %% [markdown]
# #### Extracting Belarus data without using Function:

# %%
belarus = who[who.Country == "Belarus"]
belarus
# Out:
#       Date_reported  Country  New_cases  Cumulative_cases  New_deaths  \
# 1062     2020-02-29  Belarus          6                 6           0
# 1088     2020-03-01  Belarus          0                 6           0
# 1152     2020-03-02  Belarus          0                 6           0
# 1242     2020-03-03  Belarus          0                 6           0
# 1302     2020-03-04  Belarus          4                10           0
# ...             ...      ...        ...               ...         ...
# 30876    2020-07-27  Belarus        130             67132           4
# 31059    2020-07-28  Belarus        234             67366           9
# 31239    2020-07-29  Belarus        152             67518           5
# 31610    2020-07-30  Belarus        147             67665           5
# 31667    2020-07-31  Belarus        143             67808           6
#
#        Cumulative_deaths
# 1062                   0
# 1088                   0
# 1152                   0
# ...

# %% [markdown]
# * Irregular Graph

# %%
plt.plot(belarus.Date_reported, belarus.New_cases)
plt.show()   # this graph has no pattren(irregular graph)

# %%
belarus.New_cases.max()       #to extract maximum value
# Out:
# 1934

# %%
belarus[belarus.New_cases == 1934]     #to extract all data of maximum value
# Out:
#       Date_reported  Country  New_cases  Cumulative_cases  New_deaths  \
# 14628    2020-05-13  Belarus       1934             25840          14
#
#        Cumulative_deaths
# 14628                149

# %% [markdown]
# Note: Result shows that
# * Graph of India is "Exponential"
# * Graph of Poland is "Linear"
# * Graph of Italy is "Logistic"
# * Graph of Belarus is "Irregular"
